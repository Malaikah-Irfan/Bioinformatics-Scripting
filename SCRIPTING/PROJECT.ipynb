# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data=pd.read_csv(r"C:\Users\miari\Downloads\gene_expression_file.csv")
data

print(f"Number of rows (genes): {data.shape[0]}")
print(f"Number of columns (samples): {data.shape[1]}\n")
print("First few rows of the dataset:")
data.head(2)

clean_data=data.dropna()
print(f"\nAfter cleaning, number of rows: {clean_data.shape[0]}")
clean_data

columns_to_remove = ['Gene Name'] 
final_data=clean_data.drop(columns=columns_to_remove)
final_data

mean_values = np.mean(final_data, axis=1)
median_values = np.median(final_data, axis=1)
mode_values = final_data.mode(axis=1)[0]

print(f"Mean values across samples:\n\n{mean_values}")
print(f"\nMedian values across samples:\n\n{median_values}")
print(f"\nMode values across genes:\n{mode_values}")

# Analyze specific genes
gene_name = input("\nEnter a gene name for detailed analysis: ")
if gene_name in clean_data['Gene Name'].values:
    gene_data = clean_data[clean_data['Gene Name'] == gene_name].iloc[0, 1:-3]
    print(f"\nExpression values for {gene_name}:")
    print(gene_data)

# Plot the expression values
    plt.figure(figsize=(12, 6))
    plt.plot(gene_data.index, gene_data.values, marker='o', label=gene_name)
    plt.xticks(ticks=range(0, len(gene_data.index), 5), rotation=45, fontsize=8)  # Show every 5th label

    plt.title(f"Expression Levels of {gene_name}")
    plt.xlabel("Samples")
    plt.ylabel("Expression Value")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()
else:
    print(f"\nGene '{gene_name}' not found in the dataset.")
# Out:
# Number of rows (genes): 5
# Number of columns (samples): 76
#
# First few rows of the dataset:
#
# After cleaning, number of rows: 5
# Mean values across samples:
#
# 0     90.035760
# 1     57.453825
# 2     11.474211
# 3     61.689239
# 4    706.515163
# dtype: float64
#
# Median values across samples:
#
# [ 64.2842   16.1253    9.21519  47.3927  552.255  ]
#
# Mode values across genes:
# 0    20.49490
# 1     4.94577
# 2     6.65555
# 3    12.17250
# 4    24.87030
# Name: 0, dtype: float64
# Enter a gene name for detailed analysis:  PROM1
# Expression values for PROM1:
# GSM155919    41.9456
# GSM155920     53.994
# GSM155921    152.124
# GSM155922    420.626
# GSM155923    224.694
#               ...
# GSM155986    12.9594
# GSM155987    5.43789
# GSM155988    13.7995
# GSM155989    16.1253
# GSM155990    6.82637
# Name: 1, Length: 72, dtype: object

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data=pd.read_csv(r"C:\Users\miari\Downloads\gene_expression_file.csv")
data

print(f"Number of rows (genes): {data.shape[0]}")
print(f"Number of columns (samples): {data.shape[1]}\n")
print("First few rows of the dataset:")
data.head(2)

clean_data=data.dropna()
print(f"\nAfter cleaning, number of rows: {clean_data.shape[0]}")
clean_data

columns_to_remove = ['Gene Name'] 
final_data=clean_data.drop(columns=columns_to_remove)
final_data

mean_values = np.mean(final_data, axis=1)
median_values = np.median(final_data, axis=1)
mode_values = final_data.mode(axis=1)[0]

print(f"Mean values across samples:\n\n{mean_values}")
print(f"\nMedian values across samples:\n\n{median_values}")
print(f"\nMode values across genes:\n{mode_values}")

# Analyze specific genes
gene_name = input("\nEnter a gene name for detailed analysis: ")
if gene_name in clean_data['Gene Name'].values:
    gene_data = clean_data[clean_data['Gene Name'] == gene_name].iloc[0, 1:-3]
    print(f"\nExpression values for {gene_name}:")
    print(gene_data)

# Plot the expression values
    plt.figure(figsize=(12, 6))
    plt.plot(gene_data.index, gene_data.values, marker='o', label=gene_name)
    plt.xticks(ticks=range(0, len(gene_data.index), 5), rotation=45, fontsize=8)  # Show every 5th label

    plt.title(f"Expression Levels of {gene_name}")
    plt.xlabel("Samples")
    plt.ylabel("Expression Value")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()
else:
    print(f"\nGene '{gene_name}' not found in the dataset.")
# Out:
# Number of rows (genes): 5
# Number of columns (samples): 76
#
# First few rows of the dataset:
#
# After cleaning, number of rows: 5
# Mean values across samples:
#
# 0     90.035760
# 1     57.453825
# 2     11.474211
# 3     61.689239
# 4    706.515163
# dtype: float64
#
# Median values across samples:
#
# [ 64.2842   16.1253    9.21519  47.3927  552.255  ]
#
# Mode values across genes:
# 0    20.49490
# 1     4.94577
# 2     6.65555
# 3    12.17250
# 4    24.87030
# Name: 0, dtype: float64
# Enter a gene name for detailed analysis:  PROM1
# Expression values for PROM1:
# GSM155919    41.9456
# GSM155920     53.994
# GSM155921    152.124
# GSM155922    420.626
# GSM155923    224.694
#               ...
# GSM155986    12.9594
# GSM155987    5.43789
# GSM155988    13.7995
# GSM155989    16.1253
# GSM155990    6.82637
# Name: 1, Length: 72, dtype: object

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the data
data = pd.read_csv(r"C:\Users\miari\Downloads\gene_expression_file.csv")
data

# Display initial dataset information
print(f"Number of rows (genes): {data.shape[0]}")
print(f"Number of columns (samples): {data.shape[1]}\n")
print("First few rows of the dataset:")
data.head(2)

# Remove rows with missing values
clean_data = data.dropna()
print(f"\nAfter cleaning, number of rows: {clean_data.shape[0]}")
clean_data

# Remove unnecessary columns
columns_to_remove = ['Gene Name'] 
final_data = clean_data.drop(columns=columns_to_remove)
final_data

# Calculate statistics
mean_values = np.mean(final_data, axis=1)
median_values = np.median(final_data, axis=1)
mode_values = final_data.mode(axis=1)[0]

# Add calculated statistics back to the dataset
clean_data['Mean Expression'] = mean_values
clean_data['Median Expression'] = median_values
clean_data['Mode Expression'] = mode_values

# Display statistics
print(f"Mean values across samples:\n\n{mean_values}")
print(f"\nMedian values across samples:\n\n{median_values}")
print(f"\nMode values across genes:\n{mode_values}")

# Identify top genes
clean_data['Mean Expression'] = mean_values
top_genes = clean_data.nlargest(3, 'Mean Expression')[['Gene Name', 'Mean Expression']]
print("\nTop 3 highly expressed genes:")
print(top_genes)

# Analyze specific genes
gene_name = input("\nEnter a gene name for detailed analysis: ")
if gene_name in clean_data['Gene Name'].values:
    gene_data = clean_data.loc[clean_data['Gene Name'] == gene_name].drop(columns=['Gene Name', 'Mean Expression']).squeeze()
    print(f"\nExpression values for {gene_name}:")
    print(gene_data)

    # Plot the expression values
    plt.figure(figsize=(12, 6))
    plt.plot(gene_data.index, gene_data.values, marker='o', label=gene_name)
    plt.xticks(ticks=range(0, len(gene_data.index), 5), rotation=45, fontsize=8)  # Show every 5th label
    plt.title(f"Expression Levels of {gene_name}")
    plt.xlabel("Samples")
    plt.ylabel("Expression Value")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()
else:
    print(f"\nGene '{gene_name}' not found in the dataset.")
# Out:
# Number of rows (genes): 5
# Number of columns (samples): 76
#
# First few rows of the dataset:
#
# After cleaning, number of rows: 5
# Mean values across samples:
#
# 0     90.035760
# 1     57.453825
# 2     11.474211
# 3     61.689239
# 4    706.515163
# dtype: float64
#
# Median values across samples:
#
# [ 64.2842   16.1253    9.21519  47.3927  552.255  ]
#
# Mode values across genes:
# 0    20.49490
# 1     4.94577
# 2     6.65555
# 3    12.17250
# 4    24.87030
# Name: 0, dtype: float64
#
# Top 3 highly expressed genes:
#   Gene Name  Mean Expression
# 4      IGF1       706.515163
# 0     FOXO1        90.035760
# 3     PDGFA        61.689239
# Enter a gene name for detailed analysis:  IGF1
# Expression values for IGF1:
# GSM155919             866.2310
# GSM155920             487.0510
# GSM155921             552.2550
# GSM155922             119.2950
# GSM155923             507.8530
#                        ...
# GSM155991             417.4150
# GSM155992            1055.4300
# GSM155993             144.4150
# Median Expression     552.2550
# Mode Expression        24.8703
# Name: 4, Length: 77, dtype: float64
